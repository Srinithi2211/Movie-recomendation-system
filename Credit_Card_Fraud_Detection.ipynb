# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5992  6689 -0.254073  0.862468  0.751889  1.117499  2.809207  4.340815
# 5993  6692 -1.122524  0.640559  2.125913  2.175971  1.204237 -0.410311
# 5994  6703  1.142087  0.043314  0.716482  1.514842 -0.183847  0.353445
# 5995  6712 -2.093892  2.029106  1.859731  0.697003  0.237123  0.045082
# 5996  6714 -0.512242  0.754219  1.685243  0.397028 -0.044604 -0.056287
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 5992  0.108351  0.784139  0.536083  ... -0.275949 -0.381252 -0.281816
# 5993  0.906033 -0.545508  0.777763  ... -0.380893 -0.329315 -0.503876
# 5994 -0.257745 -0.096358  2.050957  ... -0.273055 -0.219412 -0.252727
# 5995  0.966172 -0.785484  1.660583  ...  0.013807  0.009551 -0.287461
# 5996  0.253860  0.170461  1.695860  ...       NaN       NaN       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# 5992  0.944541  0.231219 -0.042626 -0.125557 -0.174222    6.03    0.0
# 5993  0.282648  0.625024 -0.094957 -0.380004 -0.511501   75.17    0.0
# 5994 -0.448681  0.815641 -0.299470  0.031549  0.021938   53.23    0.0
# 5995  0.363626  0.357492 -0.538920 -1.881842 -0.176290   16.45    0.0
# 5996       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5997 entries, 0 to 5996
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    5997 non-null   int64
#  1   V1      5997 non-null   float64
#  2   V2      5997 non-null   float64
#  3   V3      5997 non-null   float64
#  4   V4      5997 non-null   float64
#  5   V5      5997 non-null   float64
#  6   V6      5997 non-null   float64
#  7   V7      5997 non-null   float64
#  8   V8      5997 non-null   float64
#  9   V9      5997 non-null   float64
#  10  V10     5997 non-null   float64
#  11  V11     5997 non-null   float64
#  12  V12     5997 non-null   float64
#  13  V13     5997 non-null   object
#  14  V14     5996 non-null   float64
#  15  V15     5996 non-null   float64
#  16  V16     5996 non-null   float64
#  17  V17     5996 non-null   float64
#  18  V18     5996 non-null   float64
#  19  V19     5996 non-null   float64
#  20  V20     5996 non-null   float64
#  21  V21     5996 non-null   float64
#  22  V22     5996 non-null   float64
#  23  V23     5996 non-null   float64
#  24  V24     5996 non-null   float64
#  25  V25     5996 non-null   float64
#  26  V26     5996 non-null   float64
#  27  V27     5996 non-null   float64
#  28  V28     5996 non-null   float64
#  29  Amount  5996 non-null   float64
#  30  Class   5996 non-null   float64
# dtypes: float64(29), int64(1), object(1)
# memory usage: 1.4+ MB

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    5993
# 1.0       3
# Name: Class, dtype: int64

# %% [markdown]
# This Dataset is highly unblanced

# %% [markdown]
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (5993, 31)
# (3, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    5993.000000
# mean       65.065528
# std       192.625987
# min         0.000000
# 25%         4.460000
# 50%        15.690000
# 75%        56.540000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      3.000000
# mean     256.310000
# std      264.880121
# min        0.000000
# 25%      119.965000
# 50%      239.930000
# 75%      384.465000
# max      529.000000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
# <ipython-input-18-4fe90e2a08db>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   credit_card_data.groupby('Class').mean()
#               Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    2692.740697 -0.267472  0.286794  0.847050  0.104770  0.001345
# 1.0    1780.000000 -2.553039  0.184644 -0.293711  2.872264  0.005330
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.194953  0.018279 -0.039018  0.401254  ...  0.055614 -0.043108
# 1.0   -0.855718 -0.549831  0.308239 -1.093098  ...  0.599742  0.294921
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.161528 -0.037869  0.029515  0.089596 -0.039826  0.024871  0.005900
# 1.0   -0.177321  0.361160 -0.020311  0.056068 -0.170050  0.015979 -0.086847
#
#            Amount
# Class
# 0.0     65.065528
# 1.0    256.310000
#
# [2 rows x 29 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 2047  1582 -0.323126  0.377375  1.716270  0.904932 -0.266827 -0.228391
# 2318  1861  1.138271 -0.136942  0.583512  0.731683 -0.444073  0.183035
# 4472  3771  1.109273 -0.689149  0.534625 -0.635737 -0.259048  1.068197
# 2568  2108 -0.386097  1.115191  1.274662  0.008660  0.254300 -0.500077
# 5141  4839  1.027224  0.716829  1.188507  4.160989 -0.015805  0.256112
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 2047  0.113757  0.076831 -0.370508  ...  0.128439  0.565972 -0.054552
# 2318 -0.351712  0.217427  0.445247  ... -0.016136  0.170775 -0.064565
# 4472 -0.873023  0.288544  0.430378  ... -0.086392 -0.089195  0.218562
# 2568  0.672194  0.037168 -0.473125  ... -0.229752 -0.534956  0.011962
# 5141  0.052898 -0.132067  0.257657  ... -0.186567 -0.176564 -0.110013
#
#            V24       V25       V26       V27       V28  Amount  Class
# 2047  0.637250 -0.485146  0.798171  0.131398  0.149123   23.00    0.0
# 2318  0.075631  0.463156  0.452212 -0.007234 -0.003889    6.99    0.0
# 4472 -1.024461 -0.117443 -0.399136  0.045989  0.012641   67.90    0.0
# 2568  0.035986 -0.216450  0.099894  0.264855  0.096023    4.56    0.0
# 5141  0.375311  0.609948  0.022915 -0.018829  0.028949   51.38    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 3653  3122 -0.299087  0.695751  0.752337 -2.231760  0.587438 -1.022936
# 3895  3467  1.242643  0.241612  0.411610  0.421072 -0.203307 -0.465527
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 3653  1.161317 -0.393878  0.879290  ...  0.006194  0.406636 -0.400641
# 3895 -0.004405 -0.074841 -0.292113  ... -0.220207 -0.637640  0.076456
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
#
#            V24       V25       V26       V27       V28  Amount  Class
# 3653 -0.447701  0.187724 -0.787687  0.238278 -0.022020    1.00    0.0
# 3895  0.016024  0.253688  0.095311 -0.028816  0.006784    0.89    0.0
# 541   0.320198  0.044519  0.177840  0.261145 -0.143276    0.00    1.0
# 623  -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00    1.0
# 4920 -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    492
# 1.0      3
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
# <ipython-input-24-586b59598b15>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_dataset.groupby('Class').mean()
#               Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    2639.408537 -0.146588  0.306769  0.743536  0.064622  0.122365
# 1.0    1780.000000 -2.553039  0.184644 -0.293711  2.872264  0.005330
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.349950  0.007944 -0.054022  0.383071  ...  0.076214 -0.085915
# 1.0   -0.855718 -0.549831  0.308239 -1.093098  ...  0.599742  0.294921
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.159004 -0.045536  0.024583  0.123073 -0.082344  0.033753  0.005390
# 1.0   -0.177321  0.361160 -0.020311  0.056068 -0.170050  0.015979 -0.086847
#
#            Amount
# Class
# 0.0     58.010163
# 1.0    256.310000
#
# [2 rows x 29 columns]

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 2047  1582 -0.323126  0.377375  1.716270  0.904932 -0.266827 -0.228391
# 2318  1861  1.138271 -0.136942  0.583512  0.731683 -0.444073  0.183035
# 4472  3771  1.109273 -0.689149  0.534625 -0.635737 -0.259048  1.068197
# 2568  2108 -0.386097  1.115191  1.274662  0.008660  0.254300 -0.500077
# 5141  4839  1.027224  0.716829  1.188507  4.160989 -0.015805  0.256112
# ...    ...       ...       ...       ...       ...       ...       ...
# 3653  3122 -0.299087  0.695751  0.752337 -2.231760  0.587438 -1.022936
# 3895  3467  1.242643  0.241612  0.411610  0.421072 -0.203307 -0.465527
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
#
#             V7        V8        V9  ...       V20       V21       V22  \
# 2047  0.113757  0.076831 -0.370508  ...  0.277813  0.128439  0.565972
# 2318 -0.351712  0.217427  0.445247  ... -0.181791 -0.016136  0.170775
# 4472 -0.873023  0.288544  0.430378  ...  0.031630 -0.086392 -0.089195
# 2568  0.672194  0.037168 -0.473125  ...  0.116085 -0.229752 -0.534956
# 5141  0.052898 -0.132067  0.257657  ... -0.044562 -0.186567 -0.176564
# ...        ...       ...       ...  ...       ...       ...       ...
# 3653  1.161317 -0.393878  0.879290  ...  0.062264  0.006194  0.406636
# 3895 -0.004405 -0.074841 -0.292113  ... -0.031109 -0.220207 -0.637640
# 541  -2.537387  1.391657 -2.770089  ...  0.126911  0.517232 -0.035049
# 623   0.325574 -0.067794 -0.270953  ...  2.102339  0.661696  0.435477
# 4920  0.562320 -0.399147 -0.238253  ... -0.430022 -0.294166 -0.932391
#
#            V23       V24       V25       V26       V27       V28  Amount
# 2047 -0.054552  0.637250 -0.485146  0.798171  0.131398  0.149123   23.00
# 2318 -0.064565  0.075631  0.463156  0.452212 -0.007234 -0.003889    6.99
# 4472  0.218562 -1.024461 -0.117443 -0.399136  0.045989  0.012641   67.90
# 2568  0.011962  0.035986 -0.216450  0.099894  0.264855  0.096023    4.56
# 5141 -0.110013  0.375311  0.609948  0.022915 -0.018829  0.028949   51.38
# ...        ...       ...       ...       ...       ...       ...     ...
# 3653 -0.400641 -0.447701  0.187724 -0.787687  0.238278 -0.022020    1.00
# 3895  0.076456  0.016024  0.253688  0.095311 -0.028816  0.006784    0.89
# 541  -0.465211  0.320198  0.044519  0.177840  0.261145 -0.143276    0.00
# 623   1.375966 -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00
# 4920  0.172726 -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93
#
# [495 rows x 30 columns]

# %%
print(Y)
# Out:
# 2047    0.0
# 2318    0.0
# 4472    0.0
# 2568    0.0
# 5141    0.0
#        ...
# 3653    0.0
# 3895    0.0
# 541     1.0
# 623     1.0
# 4920    1.0
# Name: Class, Length: 495, dtype: float64

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (495, 30) (396, 30) (99, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  1.0

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.98989898989899
